# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import plotly.express as px

# %%
df_ = pd.read_csv("../input/market-basket-analysis/Assignment-1_Data.csv", sep = ";")
df = df_.copy()
# Out:
# /tmp/ipykernel_28/4283880202.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv("../input/market-basket-analysis/Assignment-1_Data.csv", sep = ";")

# %%
df.head(10)
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
# 5  536365         SET 7 BABUSHKA NESTING BOXES         2  01.12.2010 08:26
# 6  536365    GLASS STAR FROSTED T-LIGHT HOLDER         6  01.12.2010 08:26
# 7  536366               HAND WARMER UNION JACK         6  01.12.2010 08:28
# 8  536366            HAND WARMER RED POLKA DOT         6  01.12.2010 08:28
# 9  536367        ASSORTED COLOUR BIRD ORNAMENT        32  01.12.2010 08:34
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom
# 5  7,65     17850.0  United Kingdom
# 6  4,25     17850.0  United Kingdom
# 7  1,85     17850.0  United Kingdom
# 8  1,85     17850.0  United Kingdom
# 9  1,69     13047.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  object
#  4   Price       522064 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
def check_df(dataframe, head=5):
    print("##################### Shape #####################")
    print(dataframe.shape)

    print("##################### Types #####################")
    print(dataframe.dtypes)

    print("##################### Head #####################")
    print(dataframe.head(head))

    print("##################### Tail #####################")
    print(dataframe.tail(head))

    print("##################### NA #####################")
    print(dataframe.isnull().sum())

# %%
check_df(df)
# Out:
# ##################### Shape #####################
# (522064, 7)
# ##################### Types #####################
# BillNo         object
# Itemname       object
# Quantity        int64
# Date           object
# Price          object
# CustomerID    float64
# Country        object
# dtype: object
# ##################### Head #####################
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom
# ##################### Tail #####################
#         BillNo                         Itemname  Quantity              Date  \
# 522059  581587      PACK OF 20 SPACEBOY NAPKINS        12  09.12.2011 12:50
# 522060  581587      CHILDREN'S APRON DOLLY GIRL         6  09.12.2011 12:50
# 522061  581587     CHILDRENS CUTLERY DOLLY GIRL         4  09.12.2011 12:50
# 522062  581587  CHILDRENS CUTLERY CIRCUS PARADE         4  09.12.2011 12:50
# 522063  581587     BAKING SET 9 PIECE RETROSPOT         3  09.12.2011 12:50
#
#        Price  CustomerID Country
# 522059  0,85     12680.0  France
# 522060   2,1     12680.0  France
# 522061  4,15     12680.0  France
# 522062  4,15     12680.0  France
# 522063  4,95     12680.0  France
# ##################### NA #####################
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
# Drop na values
df.dropna(inplace=True)
# Quantity and Price should be  greater than 0
df = df[df["Quantity"] > 0]
# We have to change the price column datatype as a numeric
df ['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df = df[df["Price"] > 0]

# %%
check_df(df)
# Out:
# ##################### Shape #####################
# (1537, 7)
# ##################### Types #####################
# BillNo         object
# Itemname       object
# Quantity        int64
# Date           object
# Price         float64
# CustomerID    float64
# Country        object
# dtype: object
# ##################### Head #####################
#       BillNo                            Itemname  Quantity              Date  \
# 45    536370                             POSTAGE         3  01.12.2010 08:45
# 237   536392  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1  01.12.2010 10:29
# 377   536403                             POSTAGE         1  01.12.2010 11:27
# 1113  536527                             POSTAGE         1  01.12.2010 13:04
# 4348  536779                        Bank Charges         1  02.12.2010 15:08
#
#       Price  CustomerID         Country
# 45     18.0     12583.0          France
# 237   165.0     13705.0  United Kingdom
# 377    15.0     12791.0     Netherlands
# 1113   18.0     12662.0         Germany
# 4348   15.0     15823.0  United Kingdom
# ##################### Tail #####################
#         BillNo Itemname  Quantity              Date  Price  CustomerID  \
# 521357  581493  POSTAGE         1  09.12.2011 10:10   15.0     12423.0
# 521375  581494  POSTAGE         2  09.12.2011 10:13   18.0     12518.0
# 521885  581570  POSTAGE         1  09.12.2011 11:59   18.0     12662.0
# 521922  581574  POSTAGE         2  09.12.2011 12:09   18.0     12526.0
# 521923  581578  POSTAGE         3  09.12.2011 12:16   18.0     12713.0
#
#         Country
# 521357  Belgium
# 521375  Germany
# 521885  Germany
# 521922  Germany
# 521923  Germany
# ##################### NA #####################
# BillNo        0
# Itemname      0
# Quantity      0
# Date          0
# Price         0
# CustomerID    0
# Country       0
# dtype: int64

# %%
total_sales = df
total_sales["Total_Price"] = total_sales["Price"] * total_sales["Quantity"]
#total_sales.columns
total_sales_per_customer = total_sales.groupby(["CustomerID", "Country"]).agg({"Total_Price": "sum"})
total_sales_per_customer.head(10)
# Out:
#                         Total_Price
# CustomerID Country
# 12349.0    Italy              300.0
# 12350.0    Norway              40.0
# 12352.0    Norway             280.0
# 12356.0    Portugal           324.0
# 12357.0    Switzerland         25.0
# 12358.0    Austria            240.0
# 12360.0    Austria            360.0
# 12361.0    Belgium             15.0
# 12362.0    Belgium            489.0
# 12364.0    Belgium            105.0

# %% [markdown]
# #### Top 10 Shoppers and their Countries

# %%
total_sales_per_customer.reset_index(inplace=True)
total_sales_per_customer.sort_values(by = "Total_Price", ascending = False).head(10)
# Out:
#      CustomerID         Country  Total_Price
# 577     17450.0  United Kingdom      10496.0
# 471     15581.0  United Kingdom       2750.0
# 67      12471.0         Germany       2400.0
# 412     14607.0  United Kingdom       2120.0
# 112     12540.0           Spain       1820.0
# 246     12748.0  United Kingdom       1788.0
# 460     15482.0  United Kingdom       1646.0
# 414     14646.0     Netherlands       1458.0
# 201     12681.0          France       1422.0
# 198     12678.0          France       1297.0

# %%
# consider that for all time period
data_fig = total_sales_per_customer.sort_values(by = "Total_Price", ascending = False).head(100)

fig = px.scatter(data_fig, x="CustomerID", y="Total_Price",
	         size="Total_Price", color="Country",
                 hover_name="Country", log_x=True, size_max=60, title="Top 100 Shoppers and Their Countries & Shopping Amounts")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="8f64570e-5aaa-4fa9-b629-2a88053a523f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f64570e-5aaa-4fa9-b629-2a88053a523f")) {                    Plotly.newPlot(                        "8f64570e-5aaa-4fa9-b629-2a88053a523f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=United Kingdom<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom"],"legendgroup":"United Kingdom","marker":{"color":"#636efa","size":[10496.0,2750.0,2120.0,1788.0,1646.0,1105.0,870.0,750.0,655.0,600.0,590.0,545.0,545.0,525.0,500.0,500.0,500.0,500.0,500.0,480.0,455.0,455.0,440.0,440.0,440.0,392.0,390.0,375.0,350.0,330.0,330.0,295.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"United Kingdom","orientation":"v","showlegend":true,"x":[17450.0,15581.0,14607.0,12748.0,15482.0,17500.0,13983.0,14973.0,14711.0,15299.0,13452.0,17406.0,16607.0,16949.0,17690.0,16003.0,15727.0,16316.0,15159.0,17949.0,12909.0,14030.0,13631.0,18233.0,15524.0,14195.0,17581.0,15874.0,16873.0,14088.0,13523.0,13145.0],"xaxis":"x","y":[10496.0,2750.0,2120.0,1788.0,1646.0,1105.0,870.0,750.0,655.0,600.0,590.0,545.0,545.0,525.0,500.0,500.0,500.0,500.0,500.0,480.0,455.0,455.0,440.0,440.0,440.0,392.0,390.0,375.0,350.0,330.0,330.0,295.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Germany<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany"],"legendgroup":"Germany","marker":{"color":"#EF553B","size":[2400.0,1278.0,972.0,918.0,666.0,666.0,630.0,630.0,576.0,576.0,540.0,523.0,504.0,493.0,486.0,396.0,396.0,360.0,306.0,306.0,306.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":[12471.0,12621.0,12569.0,12476.0,12626.0,12720.0,12668.0,12474.0,12647.0,12481.0,12524.0,12590.0,12472.0,12712.0,12705.0,12627.0,12480.0,13815.0,12619.0,12662.0,12709.0],"xaxis":"x","y":[2400.0,1278.0,972.0,918.0,666.0,666.0,630.0,630.0,576.0,576.0,540.0,523.0,504.0,493.0,486.0,396.0,396.0,360.0,306.0,306.0,306.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Spain<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["Spain","Spain","Spain","Spain"],"legendgroup":"Spain","marker":{"color":"#00cc96","size":[1820.0,728.0,616.0,588.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"Spain","orientation":"v","showlegend":true,"x":[12540.0,12502.0,12597.0,12484.0],"xaxis":"x","y":[1820.0,728.0,616.0,588.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Netherlands<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["Netherlands"],"legendgroup":"Netherlands","marker":{"color":"#ab63fa","size":[1458.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"Netherlands"," ...

# %%
# consider that for all time period
#total_sales_per_customer.head(20)
total_sales_per_customer.groupby(["Country"]).agg({"Total_Price":"sum"}).reset_index().sort_values(by="Total_Price", ascending=False )
# Out:
#            Country  Total_Price
# 17  United Kingdom      53159.0
# 4          Germany      21155.0
# 3           France      15713.0
# 14           Spain       5917.0
# 2          Belgium       4269.0
# 16     Switzerland       4027.0
# 10          Norway       2996.0
# 12        Portugal       2508.0
# 9      Netherlands       1947.0
# 7            Italy       1663.0
# 15          Sweden       1539.0
# 1          Austria       1456.0
# 8            Malta        655.0
# 11          Poland        360.0
# 0        Australia        350.0
# 5           Greece        335.0
# 13       Singapore        315.0
# 6           Israel        255.0

# %%
# consider that for all time period
data = total_sales_per_customer.groupby(["Country"]).agg({"Total_Price":"sum"}).reset_index().sort_values(by="Total_Price", ascending=False )
fig = px.bar(data, x='Country', y='Total_Price' , title = "Shopping Amounts by Countries")
fig.show()
# Out:
# <div>                            <div id="0c3a4caf-3d8a-4e18-90c0-1f8b211d1505" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c3a4caf-3d8a-4e18-90c0-1f8b211d1505")) {                    Plotly.newPlot(                        "0c3a4caf-3d8a-4e18-90c0-1f8b211d1505",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total_Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United Kingdom","Germany","France","Spain","Belgium","Switzerland","Norway","Portugal","Netherlands","Italy","Sweden","Austria","Malta","Poland","Australia","Greece","Singapore","Israel"],"xaxis":"x","y":[53159.0,21155.0,15713.0,5917.0,4269.0,4027.0,2996.0,2508.0,1947.0,1663.0,1539.0,1456.0,655.0,360.0,350.0,335.0,315.0,255.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"mark ...

# %%
#df_united_kingdom = df.loc[df["Country"]=="United Kingdom"]
df_invoice_product_matrix = df.groupby(['BillNo', 'Itemname']).  \
    agg({"Quantity": "sum"}).unstack().fillna(0).  \
    applymap(lambda x: 1 if x > 0 else 0)

df_invoice_product_matrix.head(10)
# Out:
#                                  Quantity                             \
# Itemname BEADED CHANDELIER T-LIGHT HOLDER BILI NUT AND WOOD NECKLACE
# BillNo
# 536370                                  0                          0
# 536392                                  0                          0
# 536403                                  0                          0
# 536527                                  0                          0
# 536779                                  0                          0
# 536835                                  0                          0
# 536840                                  0                          0
# 536852                                  0                          0
# 536858                                  0                          0
# 536861                                  0                          0
#
#                                                             \
# Itemname BLING KEY RING STAND BOTANICAL GARDENS WALL CLOCK
# BillNo
# 536370                      0                            0
# 536392                      0                            0
# 536403                      0                            0
# 536527                      0                            0
# 536779                      0                            0
# 536835                      0                            0
# 536840                      0                            0
# 536852                      0                            0
# 536858                      0                            0
# 536861                      0                            0
#
#                                                                \
# Itemname BREAD BIN DINER STYLE PINK BREAD BIN DINER STYLE RED
# BillNo
# 536370                            0                         0
# 536392                            0                         0
# 536403                            0                         0
# 536527                            0                         0
# 536779                            0                         0
# 536835                            0                         0
# 536840                            0                         0
# 536852                            0                         0
# 536858                            0                         0
# 536861                            0                         0
#
#                                                                      \
# Itemname BROWN CHECK CAT DOORSTOP BROWN KUKUI COCONUT SEED NECKLACE
# BillNo
# 536370                          0                                 0
# 536392                          0                                 0
# 536403                          0                                 0
# 536527                          0                                 0
# 536779                          0                                 0
# 536835                          0                                 0
# 536840                          0                                 0
# 536852                          0                                 0
# 536858                          0                                 0
# 536861                          0                                 0
#
#                                                          ...  \
# Itemname Bank Charges CAKE STAND VICTORIAN FILIGREE MED  ...
# BillNo                                                   ...
# 536370              0                                 0  ...
# 536392              0                                 0  ...
# 536403              0                                 0  ...
# 536527              0                                 0  ...
# 536779              1                                 0  ...
# 536835              0                                 0  ...
# 536840              0                                 0  ...
# 536852              0                                 0  ...
# 536858              0                                 0  ...
# 536861              0                                 0  ...
#
#                                                                                \
# Itemname SMALL WHITE RETROSPOT MUG IN BOX SPOTTED WHITE NATURAL SEED NECKLACE
# BillNo
# 536370                                  0                                   0
# 536392                                  0                                   0
# 536403                                  0                                   0
# 536527                                  0                                   0
# 536779                                  0                                   0
# 536835                                  0                                   0
# 536840                                  0                                   0
# 536852                                  0                                   0
# 536858                                  0                                   0
# 536861                                  0                                   0
#
#                                                            \
# Itemname TWO DOOR CURIO CABINET UTILTY CABINET WITH HOOKS
# BillNo
# 536370                        0                         0
# 536392                        0                         0
# 536403                        0                         0
# 536527                        0                         0
# 536779                        0                         0
# 536835                        0                         0
# 536840                        0                         0
# 536852                        0                         0
# 536858                        0                         0
# 536861                        0                         0
#
#                                                                        \
# Itemname VANILLA SCENT CANDLE JEWELLED BOX VICTORIAN SEWING BOX SMALL
# BillNo
# 536370                                   0                          0
# 536392                                   0                          0
# 536403                                   0                          0
# 536527                                   0                          0
# 536779                                   0                          0
# 536835                                   0                          0
# 536840                                   0                          0
# 536852                                   0                          0
# 536858                                   0                          0
# 536861                                   0                          0
#
#                                                                    \
# Itemname VINTAGE BLUE KITCHEN CABINET VINTAGE RED KITCHEN CABINET
# BillNo
# 536370                              0                           0
# 536392                              0                           0
# 536403                              0                           0
# 536527                              0                           0
# 536779                              0                           0
# 536835                              0                           1
# 536840                              0                           0
# 536852                              0                           0
# 536858                              0                           0
# 536861                              0                           0
#
#
# Itemname VINTAGE WOODEN BAR STOOL WOODEN ADVENT CALENDAR CREAM
# BillNo
# 536370                          0                            0
# 536392                          0                            0
# 536403                          0                            0
# 536527                          0                            0
# 536779                          0                            0
# 536835                          0                            0
# 536840                          0                            0
# 536852                          0                            0
# 536858                          0                            0
# 536861                          0                            0
#
# [10 rows x 73 columns]

# %%
frequent_itemsets = apriori(df_invoice_product_matrix, min_support=0.001, use_colnames=True) 
frequent_itemsets.sort_values("support", ascending=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning:
#
# DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#        support                                           itemsets
# 30    0.715076                              ((Quantity, POSTAGE))
# 27    0.054633                    ((Quantity, Next Day Carriage))
# 3     0.043568         ((Quantity, BOTANICAL GARDENS WALL CLOCK))
# 26    0.031120                               ((Quantity, Manual))
# 23    0.027663        ((Quantity, LOVE SEAT ANTIQUE WHITE METAL))
# ...        ...                                                ...
# 573   0.001383  ((Quantity, DOORMAT FANCY FONT HOME SWEET HOME...
# 574   0.001383  ((Quantity, DOORMAT FANCY FONT HOME SWEET HOME...
# 575   0.001383  ((Quantity, DOORMAT FANCY FONT HOME SWEET HOME...
# 576   0.001383  ((Quantity, DOORMAT FANCY FONT HOME SWEET HOME...
# 1084  0.001383  ((Quantity, DOORMAT FANCY FONT HOME SWEET HOME...
#
# [1085 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="support", min_threshold=0.001)
rules.sort_values("support", ascending=False).head(10)
# Out:
#                                            antecedents  \
# 123         ((Quantity, VINTAGE BLUE KITCHEN CABINET))
# 122          ((Quantity, VINTAGE RED KITCHEN CABINET))
# 17   ((Quantity, SPOTTED WHITE NATURAL SEED NECKLACE))
# 14     ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))
# 137  ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE)...
# 138  ((Quantity, RED KUKUI COCONUT SEED NECKLACE), ...
# 139    ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))
# 140      ((Quantity, RED KUKUI COCONUT SEED NECKLACE))
# 141           ((Quantity, BILI NUT AND WOOD NECKLACE))
# 119  ((Quantity, SPOTTED WHITE NATURAL SEED NECKLACE))
#
#                                            consequents  antecedent support  \
# 123          ((Quantity, VINTAGE RED KITCHEN CABINET))            0.012448
# 122         ((Quantity, VINTAGE BLUE KITCHEN CABINET))            0.024896
# 17     ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))            0.003458
# 14       ((Quantity, RED KUKUI COCONUT SEED NECKLACE))            0.004149
# 137      ((Quantity, RED KUKUI COCONUT SEED NECKLACE))            0.002766
# 138    ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))            0.002766
# 139  ((Quantity, RED KUKUI COCONUT SEED NECKLACE), ...            0.004149
# 140  ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE)...            0.007607
# 141  ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE)...            0.002766
# 119      ((Quantity, RED KUKUI COCONUT SEED NECKLACE))            0.003458
#
#      consequent support   support  confidence        lift  leverage  \
# 123            0.024896  0.006916    0.555556   22.314815  0.006606
# 122            0.012448  0.006916    0.277778   22.314815  0.006606
# 17             0.004149  0.002766    0.800000  192.800000  0.002752
# 14             0.007607  0.002766    0.666667   87.636364  0.002735
# 137            0.007607  0.002766    1.000000  131.454545  0.002745
# 138            0.004149  0.002766    1.000000  241.000000  0.002755
# 139            0.002766  0.002766    0.666667  241.000000  0.002755
# 140            0.002766  0.002766    0.363636  131.454545  0.002745
# 141            0.002766  0.002766    1.000000  361.500000  0.002759
# 119            0.007607  0.002766    0.800000  105.163636  0.002740
#
#      conviction  zhangs_metric
# 123    2.193983       0.967227
# 122    1.367380       0.979574
# 17     4.979253       0.998265
# 14     2.977178       0.992708
# 137         inf       0.995146
# 138         inf       0.998613
# 139    2.991701       1.000000
# 140    1.567082       1.000000
# 141         inf       1.000000
# 119    4.961964       0.993928

# %%
sorted_rules = rules.sort_values("lift", ascending=False)
rules.sort_values("lift", ascending=False).head(10)
# Out:
#                                              antecedents  \
# 113    ((Quantity, MARIE ANTOINETTE TRINKET BOX SILVER))
# 114      ((Quantity, VANILLA SCENT CANDLE JEWELLED BOX))
# 112      ((Quantity, MARIE ANTOINETTE TRINKET BOX GOLD))
# 115     ((Quantity, OCEAN SCENT CANDLE IN JEWELLED BOX))
# 38147  ((Quantity, DOORMAT MERRY CHRISTMAS RED), (Qua...
# 38078  ((Quantity, DOORMAT UNION FLAG), (Quantity, DO...
# 38067  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 38068  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 38069  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 38070  ((Quantity, DOORMAT RESPECTABLE HOUSE), (Quant...
#
#                                              consequents  antecedent support  \
# 113      ((Quantity, MARIE ANTOINETTE TRINKET BOX GOLD))            0.001383
# 114     ((Quantity, OCEAN SCENT CANDLE IN JEWELLED BOX))            0.001383
# 112    ((Quantity, MARIE ANTOINETTE TRINKET BOX SILVER))            0.001383
# 115      ((Quantity, VANILLA SCENT CANDLE JEWELLED BOX))            0.001383
# 38147  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...            0.001383
# 38078  ((Quantity, DOORMAT NEW ENGLAND), (Quantity, D...            0.001383
# 38067  ((Quantity, DOORMAT FAIRY CAKE), (Quantity, DO...            0.001383
# 38068  ((Quantity, DOORMAT NEW ENGLAND), (Quantity, D...            0.001383
# 38069  ((Quantity, DOORMAT MERRY CHRISTMAS RED), (Qua...            0.002075
# 38070  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...            0.001383
#
#        consequent support   support  confidence   lift  leverage  conviction  \
# 113              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 114              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 112              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 115              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 38147            0.002075  0.001383    1.000000  482.0  0.001380         inf
# 38078            0.002075  0.001383    1.000000  482.0  0.001380         inf
# 38067            0.002075  0.001383    1.000000  482.0  0.001380         inf
# 38068            0.002075  0.001383    1.000000  482.0  0.001380         inf
# 38069            0.001383  0.001383    0.666667  482.0  0.001380    2.995851
# 38070            0.002075  0.001383    1.000000  482.0  0.001380         inf
#
#        zhangs_metric
# 113         1.000000
# 114         1.000000
# 112         1.000000
# 115         1.000000
# 38147       0.999307
# 38078       0.999307
# 38067       0.999307
# 38068       0.999307
# 38069       1.000000
# 38070       0.999307

# %%
# We can try below products in the loop
# ('Quantity', 'VANILLA SCENT CANDLE JEWELLED BOX')
# ('Quantity', 'DOORMAT MERRY CHRISTMAS RED')
# ('Quantity', 'DOORMAT RESPECTABLE HOUSE')
# ('Quantity', 'DOORMAT SPOTTY HOME SWEET HOME')
# ('Quantity', 'DOORMAT UNION FLAG')
# ('Quantity', 'DOORMAT UNION FLAG')

recommendation_list = []

for i, product in sorted_rules["antecedents"].items():
    for j in list(product):
        if j == ('Quantity', 'MARIE ANTOINETTE TRINKET BOX GOLD'):
            recommendation_list.append(list(sorted_rules.iloc[i]["consequents"]))

# %%
recommendation_list
# Out:
# [[('Quantity', 'DOORMAT UNION FLAG'),
#   ('Quantity', 'DOORMAT NEW ENGLAND'),
#   ('Quantity', 'DOORMAT HEARTS'),
#   ('Quantity', 'DOORMAT RESPECTABLE HOUSE')]]
